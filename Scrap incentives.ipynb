# %%
import requests
from bs4 import BeautifulSoup
import pickle
import re
import random
import itertools
import networkx as nx
import collections
import numpy as np
import operator
import pandas as pd

# %%
### PART 1: LOADING LINKS FROM ARCHIVES
url = "http://programs.dsireusa.org/system/program?technology=7&"
#url='http://programs.dsireusa.org/api/v1/getprograms/xml'
#links_list=[]
#scrap selectively for page 2, discard all after dec 1, 2014
response = requests.get(url)
soup = BeautifulSoup(response.text)
soup
#test=soup.findAll('table')[0].findAll('tr')
#parent_div=soup.find_all('table', attrs={"class":'row-border'})
#print parent_div
#parent_div = soup.find_all('tr', attrs={"role":'row'}) #Find (at most) *one*
#tech_divs = soup.find_all('tr', attrs={'role':'row'})  #Find *all*
#tech_divs
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" data-ng-app="ncsolar"> <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" data-ng-app="ncsolar"> <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" data-ng-app="ncsolar"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" data-ng-app="ncsolar" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="on" http-equiv="cleartype"/>
# <title>DSIRE </title> <meta content="width=device-width, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# ...

# %%
test
# Out:
# []

# %%
soup.tbody.find_all('tr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-7e220402bdb6> in <module>()
# ----> 1 soup.tbody.find_all('tr')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
